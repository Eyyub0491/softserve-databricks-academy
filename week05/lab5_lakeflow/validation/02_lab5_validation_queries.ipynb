# %%
# %sql
CREATE CATALOG IF NOT EXISTS lab5;

CREATE SCHEMA IF NOT EXISTS lab5.bronze;
CREATE SCHEMA IF NOT EXISTS lab5.silver;

CREATE VOLUME IF NOT EXISTS lab5.bronze.checkpoints;

# %%
# %sql
DESCRIBE TABLE lab5.bronze.brz_customers;

# %%
# %sql

SELECT * FROM lab5.bronze.brz_sales_orders LIMIT 10;

# %%
# %sql
SELECT COUNT(*) AS customer_rows
FROM lab5.bronze.brz_customers;

SELECT COUNT(*) AS sales_order_rows,
       COUNT(DISTINCT order_number) AS distinct_order_numbers
FROM lab5.bronze.brz_sales_orders;

DESCRIBE TABLE lab5.bronze.brz_customers;

DESCRIBE TABLE lab5.bronze.brz_sales_orders;

# %%
# %sql
DESCRIBE TABLE lab5.bronze.brz_customers;

# %%
# %sql
SELECT COUNT(*) AS clean_customers
FROM lab5.silver.slv_customers_clean;

SELECT COUNT(*) AS clean_orders
FROM lab5.silver.slv_sales_orders_clean;

SELECT
  COUNT(*) AS customer_versions,
  SUM(CASE WHEN __END_AT IS NULL THEN 1 ELSE 0 END) AS active_customer_versions
FROM lab5.silver.slv_customers_history;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS lab5.bronze.customer_landing;

# %%
# %sql
SELECT
  customer_id,
  city,
  loyalty_segment,
  __START_AT,
  __END_AT
FROM lab5.silver.slv_customers_history
WHERE customer_id = 'SCD_DEMO_001';
